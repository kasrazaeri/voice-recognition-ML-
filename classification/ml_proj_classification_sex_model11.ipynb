# %%
import pickle
from tkinter.tix import COLUMN
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
from sklearn.metrics import accuracy_score
from itertools import combinations
from sklearn.base import clone
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
#import matplotlib as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import make_pipeline
from sklearn import preprocessing
from sklearn.metrics import accuracy_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/model1/model1_csv/Train.csv')
train=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/model1/model1_excel/Train.csv')
emotion_train = train["emotionID"]
set(emotion_train)
result = pd.concat([df, train["sex"],emotion_train], axis=1)
df_train=result.drop(columns=["target"])
df_train["sex"].replace({"f": 0, "m": 1}, inplace=True)
df_train
# Out:
#                                             Unnamed: 0  harmonic_0     rms_0  \
# 0      C:/Users/vcc/Desktop/project ml/voice/10134.wav           1  0.207221
# 1       C:/Users/vcc/Desktop/project ml/voice/8531.wav           0  0.226640
# 2       C:/Users/vcc/Desktop/project ml/voice/3858.wav           1  0.188232
# 3      C:/Users/vcc/Desktop/project ml/voice/15282.wav           0  0.337973
# 4       C:/Users/vcc/Desktop/project ml/voice/8886.wav           1  0.275328
# ...                                                ...         ...       ...
# 11992    C:/Users/vcc/Desktop/project ml/voice/667.wav           1  0.212084
# 11993    C:/Users/vcc/Desktop/project ml/voice/550.wav           1  0.377174
# 11994   C:/Users/vcc/Desktop/project ml/voice/3617.wav           0  0.269279
# 11995   C:/Users/vcc/Desktop/project ml/voice/6543.wav           0  0.377032
# 11996   C:/Users/vcc/Desktop/project ml/voice/6783.wav           1  0.526285
#
#           rms_1     rms_2     rms_3     rms_4     rms_5     rms_6     rms_7  \
# 0      0.186255  0.202790  0.202172  0.253855  0.252830  0.290057  0.477757
# 1      0.259669  0.207536  0.233701  0.271118  0.334941  0.331322  0.351121
# 2      0.387824  0.183417  0.158341  0.228774  0.295588  0.370402  0.242210
# 3      0.266403  0.250867  0.224357  0.281606  0.344213  0.254094  0.218870
# 4      0.300721  0.321282  0.287005  0.237008  0.232479  0.248921  0.345199
# ...         ...       ...       ...       ...       ...       ...       ...
# 11992  0.231472  0.254078  0.176014  0.175327  0.343146  0.402332  0.324998
# 11993  0.310318  0.312310  0.195373  0.104358  0.159201  0.228182  0.207928
# 11994  0.339664  0.338829  0.335618  0.245934  0.232261  0.288918  0.277685
# 11995  0.390642  0.308351  0.257082  0.276454  0.266963  0.204464  0.185196
# 11996  0.330948  0.211807  0.062411  0.086675  0.144215  0.193451  0.268743
#
#        ...  tempogram_382  tempogram_383  tonnetz_0  tonnetz_1  tonnetz_2  \
# 0      ...   1.070700e-17   1.268245e-17   0.013349   0.028258   0.052678
# 1      ...   5.140642e-18   1.320620e-17  -0.000083   0.020476  -0.023280
# 2      ...   2.709129e-17   2.850107e-17  -0.012416  -0.099311  -0.105882
# 3      ...   1.593020e-17   3.133522e-17  -0.000153   0.033054  -0.014428
# 4      ...   9.862421e-18   1.462932e-17  -0.009244   0.013226   0.036559
# ...    ...            ...            ...        ...        ...        ...
# 11992  ...   1.452712e-18  -7.845835e-18  -0.022032   0.007884  -0.014602
# 11993  ...   7.927351e-18  -6.857078e-19   0.000415  -0.007255   0.048274
# 11994  ...   5.622038e-18   8.571287e-18  -0.018494   0.000523   0.058501
# 11995  ...  -1.333271e-19   1.950828e-17  -0.008947  -0.011518  -0.020484
# 11996  ...   1.094576e-17   5.801311e-18   0.028950   0.069153   0.017202
#
#        tonnetz_3  tonnetz_4  tonnetz_5  sex  emotionID
# 0       0.034062   0.003144  -0.018690    0          3
# 1      -0.028995   0.015221   0.002781    1          3
# 2      -0.105014   0.044064   0.009831    0          2
# 3       0.007295   0.003092   0.005574    1          2
# 4      -0.019308   0.002719  -0.008044    1          1
# ...          ...        ...        ...  ...        ...
# 11992  -0.048042   0.002554   0.002439    0          1
# 11993  -0.042281  -0.011262  -0.003376    1          4
# 11994  -0.050269   0.025037   0.001923    1          1
# 11995   0.016671   0.006129  -0.011704    1          3
# 11996   0.057091  -0.000254   0.025836    0          3
#
# [11997 rows x 420 columns]

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/model1/model1_csv/Test.csv')
train=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/model1/model1_excel/Test.csv')
emotion_train = train["emotionID"]
set(emotion_train)
result = pd.concat([df, train["sex"],emotion_train], axis=1)
df_test=result.drop(columns=["target"])
df_test["sex"].replace({"f": 0, "m": 1}, inplace=True)
df_test
# Out:
#                                            Unnamed: 0  harmonic_0     rms_0  \
# 0      C:/Users/vcc/Desktop/project ml/voice/7478.wav           1  0.270149
# 1     C:/Users/vcc/Desktop/project ml/voice/16498.wav           1  0.223742
# 2      C:/Users/vcc/Desktop/project ml/voice/5161.wav           0  0.230485
# 3     C:/Users/vcc/Desktop/project ml/voice/12044.wav           0  0.266159
# 4     C:/Users/vcc/Desktop/project ml/voice/11125.wav           1  0.185756
# ...                                               ...         ...       ...
# 3328   C:/Users/vcc/Desktop/project ml/voice/8959.wav           1  0.284114
# 3329   C:/Users/vcc/Desktop/project ml/voice/6085.wav           0  0.360032
# 3330   C:/Users/vcc/Desktop/project ml/voice/3598.wav           0  0.470250
# 3331   C:/Users/vcc/Desktop/project ml/voice/7310.wav           1  0.210148
# 3332  C:/Users/vcc/Desktop/project ml/voice/15832.wav           0  0.195514
#
#          rms_1     rms_2     rms_3     rms_4     rms_5     rms_6     rms_7  \
# 0     0.256338  0.217479  0.202352  0.242876  0.243861  0.264635  0.277442
# 1     0.250097  0.211908  0.222841  0.240584  0.219317  0.224211  0.210208
# 2     0.235585  0.142603  0.145276  0.152412  0.194721  0.390364  0.508089
# 3     0.214282  0.160829  0.162888  0.208786  0.267876  0.296525  0.402936
# 4     0.101775  0.053663  0.165501  0.184857  0.289909  0.382493  0.405568
# ...        ...       ...       ...       ...       ...       ...       ...
# 3328  0.232915  0.234687  0.186644  0.212548  0.221596  0.214946  0.193321
# 3329  0.290603  0.284823  0.307523  0.275772  0.299312  0.272161  0.260436
# 3330  0.460255  0.365054  0.224347  0.193602  0.086986  0.019533  0.087441
# 3331  0.208596  0.162438  0.146853  0.145155  0.304987  0.316568  0.424251
# 3332  0.155731  0.157167  0.344477  0.591368  0.372985  0.243739  0.245534
#
#       ...  tempogram_382  tempogram_383  tonnetz_0  tonnetz_1  tonnetz_2  \
# 0     ...   1.927423e-17   3.212614e-17   0.010602   0.006670  -0.015999
# 1     ...   1.512772e-17   2.749622e-17  -0.023684  -0.029653  -0.015989
# 2     ...   2.182835e-17   4.185631e-17   0.002788   0.005571   0.066771
# 3     ...   3.937976e-18   1.065105e-17  -0.007513   0.009847   0.039396
# 4     ...   1.390310e-17   6.229200e-18   0.027808  -0.018923   0.047101
# ...   ...            ...            ...        ...        ...        ...
# 3328  ...   1.050115e-17   1.234963e-17   0.007097   0.005714  -0.027216
# 3329  ...   8.058911e-18   1.476203e-17  -0.002840   0.039708   0.003486
# 3330  ...   6.492927e-18   1.283503e-17   0.037189  -0.035837   0.019340
# 3331  ...   2.978539e-17   3.567139e-17  -0.012839   0.025929  -0.031925
# 3332  ...   3.237822e-17   3.740364e-17   0.054398  -0.041374  -0.002544
#
#       tonnetz_3  tonnetz_4  tonnetz_5  sex  emotionID
# 0      0.019672   0.000995  -0.003964    1          2
# 1      0.000457  -0.010479  -0.008076    1          2
# 2      0.028448   0.018775   0.010006    0          1
# 3      0.058029  -0.002884  -0.012609    0          3
# 4     -0.022189  -0.002145   0.012433    1          4
# ...         ...        ...        ...  ...        ...
# 3328  -0.016999   0.002110  -0.000767    1          2
# 3329   0.005680   0.002546   0.012637    1          1
# 3330   0.064211  -0.008946  -0.019302    1          2
# 3331   0.006267  -0.015445  -0.010247    0          2
# 3332   0.168455   0.051327  -0.024890    1          4
#
# [3333 rows x 420 columns]

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/model1/model1_csv/Val.csv')
train=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/model1/model1_excel/Validation.csv')
emotion_train = train["emotionID"]
set(emotion_train)
result = pd.concat([df, train["sex"],emotion_train], axis=1)
df_val=result.drop(columns=["target"])
df_val["sex"].replace({"f": 0, "m": 1}, inplace=True)
df_val
# Out:
#                                            Unnamed: 0  harmonic_0     rms_0  \
# 0      C:/Users/vcc/Desktop/project ml/voice/7194.wav           1  0.226163
# 1      C:/Users/vcc/Desktop/project ml/voice/2711.wav           1  0.386440
# 2       C:/Users/vcc/Desktop/project ml/voice/693.wav           0  0.388880
# 3     C:/Users/vcc/Desktop/project ml/voice/12240.wav           0  0.242110
# 4     C:/Users/vcc/Desktop/project ml/voice/10319.wav           0  0.366268
# ...                                               ...         ...       ...
# 1328   C:/Users/vcc/Desktop/project ml/voice/9790.wav           1  0.157065
# 1329  C:/Users/vcc/Desktop/project ml/voice/11515.wav           1  0.342686
# 1330  C:/Users/vcc/Desktop/project ml/voice/15054.wav           0  0.294088
# 1331  C:/Users/vcc/Desktop/project ml/voice/10839.wav           0  0.243249
# 1332   C:/Users/vcc/Desktop/project ml/voice/4870.wav           0  0.141807
#
#          rms_1     rms_2     rms_3     rms_4     rms_5     rms_6     rms_7  \
# 0     0.192117  0.191667  0.273537  0.258063  0.369499  0.283451  0.246573
# 1     0.258740  0.214219  0.297217  0.254436  0.253013  0.138033  0.205372
# 3331   C:/Users/vcc/Desktop/project ml/voice/7310.wav           1  0.210148
# 3332  C:/Users/vcc/Desktop/project ml/voice/15832.wav           0  0.195514
#
#          rms_1     rms_2     rms_3     rms_4     rms_5     rms_6     rms_7  \
# 0     0.186255  0.202790  0.202172  0.253855  0.252830  0.290057  0.477757
# 1     0.259669  0.207536  0.233701  0.271118  0.334941  0.331322  0.351121
# 2     0.387824  0.183417  0.158341  0.228774  0.295588  0.370402  0.242210
# 3     0.266403  0.250867  0.224357  0.281606  0.344213  0.254094  0.218870
# 4     0.300721  0.321282  0.287005  0.237008  0.232479  0.248921  0.345199
# ...        ...       ...       ...       ...       ...       ...       ...
# 3328  0.232915  0.234687  0.186644  0.212548  0.221596  0.214946  0.193321
# 3329  0.290603  0.284823  0.307523  0.275772  0.299312  0.272161  0.260436
# 3330  0.460255  0.365054  0.224347  0.193602  0.086986  0.019533  0.087441
# 3331  0.208596  0.162438  0.146853  0.145155  0.304987  0.316568  0.424251
# 3332  0.155731  0.157167  0.344477  0.591368  0.372985  0.243739  0.245534
#
#       ...  tempogram_382  tempogram_383  tonnetz_0  tonnetz_1  tonnetz_2  \
# 0     ...   1.070700e-17   1.268245e-17   0.013349   0.028258   0.052678
# 1     ...   5.140642e-18   1.320620e-17  -0.000083   0.020476  -0.023280
# 2     ...   2.709129e-17   2.850107e-17  -0.012416  -0.099311  -0.105882
# 3     ...   1.593020e-17   3.133522e-17  -0.000153   0.033054  -0.014428
# 4     ...   9.862421e-18   1.462932e-17  -0.009244   0.013226   0.036559
# ...   ...            ...            ...        ...        ...        ...
# 3328  ...   1.050115e-17   1.234963e-17   0.007097   0.005714  -0.027216
# 3329  ...   8.058911e-18   1.476203e-17  -0.002840   0.039708   0.003486
# 3330  ...   6.492927e-18   1.283503e-17   0.037189  -0.035837   0.019340
# 3331  ...   2.978539e-17   3.567139e-17  -0.012839   0.025929  -0.031925
# 3332  ...   3.237822e-17   3.740364e-17   0.054398  -0.041374  -0.002544
#
#       tonnetz_3  tonnetz_4  tonnetz_5  sex  emotionID
# 0      0.034062   0.003144  -0.018690    0          3
# 1     -0.028995   0.015221   0.002781    1          3
# 2     -0.105014   0.044064   0.009831    0          2
# 3      0.007295   0.003092   0.005574    1          2
# 4     -0.019308   0.002719  -0.008044    1          1
# ...         ...        ...        ...  ...        ...
# 3328  -0.016999   0.002110  -0.000767    1          2
# 3329   0.005680   0.002546   0.012637    1          1
# 3330   0.064211  -0.008946  -0.019302    1          2
# 3331   0.006267  -0.015445  -0.010247    0          2
# 3332   0.168455   0.051327  -0.024890    1          4
#
# [16663 rows x 420 columns]

# %% [markdown]
# # train and test split

# %%
from sklearn.model_selection import train_test_split
X = df.drop(['sex','emotionID','Unnamed: 0'],1)   #Feature Matrix
y = df["sex"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %% [markdown]
# # classification sex with pca

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.decomposition import PCA

pca = PCA(11)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
explained_variance = pca.explained_variance_ratio_
len(explained_variance)
# Out:
# 11

# %% [markdown]
# ## random forest

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(max_depth=10, random_state=0)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
print('Accuracy random forest with pca: ' , accuracy_score(y_test, y_pred))
# Out:
# Accuracy random forest with pca:  0.6633663366336634

# %% [markdown]
# # classification with out pca

# %%
X = df.drop(['sex','emotionID','Unnamed: 0'],1)   #Feature Matrix
y = df["sex"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %% [markdown]
# ## random forest

# %%
classifier = RandomForestClassifier(max_depth=10, random_state=0)
classifier=classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)
print('accuracy:\n',accuracy_score(y_test, y_pred))
# Out:
# accuracy:
#  0.7314731473147315

# %% [markdown]
# ## mlp

# %%
clf = make_pipeline(preprocessing.StandardScaler(),  MLPClassifier(solver='lbfgs', alpha=0.1,hidden_layer_sizes=(4, 2), random_state=0))
clf = clf.fit(X_train, y_train)
y_hat=clf.predict(X_test)

print('accuracy:\n',accuracy_score(y_test, y_hat))
# Out:
# accuracy:
#  0.7497749774977498
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html

# %%
# cross validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(clf, X,y, cv=10, scoring='accuracy')
scores
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# array([0.74025195, 0.72465507, 0.73065387, 0.72809124, 0.72268908,
#        0.74669868, 0.74369748, 0.74489796, 0.7304922 , 0.73889556])

# %% [markdown]
# # lda

# %%
from sklearn.preprocessing import StandardScaler,scale
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

X_train = scale(X_train)
#X_train = sc.fit_transform(X_train)
X_test=scale(X_test)
#X_test = sc.transform(X_test)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

lda = LDA(n_components=1)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn import svm
classifier = svm.SVC(kernel='poly',C=10,degree=3,gamma=0.03)

classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
print('Accuracy' ,accuracy_score(y_test, y_pred))
y_pred1 = classifier.predict(X_train)
print('Accuracy train' ,accuracy_score(y_train, y_pred1))
# Out:
# Accuracy 0.6960696069606961
# Accuracy train 0.6582895723930983

# %% [markdown]
# ## naive bayes

# %%
nb = GaussianNB()

nb=nb.fit(X_train, y_train)
y_pred = nb.predict(X_test)
print('Accuracy' ,accuracy_score(y_test, y_pred))
y_pred1 = nb.predict(X_train)
print('Accuracy train' ,accuracy_score(y_train, y_pred1))
# Out:
# Accuracy 0.6039603960396039
# Accuracy train 0.7287321830457615

# %% [markdown]
# # mutual info for sex

# %%
from sklearn.feature_selection import mutual_info_classif as MIC
mi_score = MIC(X,y)
print(mi_score)
# Out:
# [3.11666843e-03 4.36008349e-03 3.95362719e-03 1.70449758e-02
#  7.60317602e-03 1.37794897e-03 7.15800541e-03 8.68313849e-03
#  8.20840165e-03 3.54000132e-03 2.41094508e-03 6.85856702e-03
#  2.81445482e-03 2.98832066e-02 1.00159443e-02 2.25242224e-02
#  2.62473960e-02 4.22169392e-02 3.28408417e-02 2.47331888e-02
#  1.98817726e-02 6.27521294e-03 8.95973546e-03 3.60438154e-03
0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 3.83224465e-03
#  4.52167536e-03 3.73548610e-03 0.00000000e+00 5.27522128e-03
#  5.45249731e-03]

# %%
plt.plot(mi_score)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# prepare dataset 2, MI > 0.2
mi_score_selected_index = np.where(mi_score > 0.01)[0]
X_2 = X[:, mi_score_selected_index]
X_train_2, X_test_2, y_train, y_test = train_test_split(
    X_2, y, random_state=0, stratify=y
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-319368ed4d92> in <module>()
#       1 # prepare dataset 2, MI > 0.2
#       2 mi_score_selected_index = np.where(mi_score > 0.01)[0]
# ----> 3 X_2 = X[:, mi_score_selected_index]
#       4 X_train_2, X_test_2, y_train, y_test = train_test_split(
#       5     X_2, y, random_state=0, stratify=y
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), array([  3,  13,  14,  15,  16,  17,  18,  19,  20,  26,  35,  86, 143,
#        233, 249]))' is an invalid key

# %%
from sklearn.datasets import fetch_openml
from sklearn.feature_selection import SelectKBest, SelectPercentile, mutual_info_classif

# %%
selector = SelectPercentile(mutual_info_classif, percentile=5)
X_reduced = selector.fit_transform(X, y)
X_reduced.shape
# Out:
# (16663, 21)

# %%
cols = selector.get_support(indices=True)
selected_columns = X.iloc[:,cols].columns.tolist()
selected_columns
# Out:
# ['rms_2',
#  'rms_3',
#  'rms_5',
#  'rms_6',
#  'rms_7',
#  'rms_10',
#  'chroma_0',
#  'zero_crossing_rate_0',
#  'chroma_stft_0',
#  'chroma_stft_1',
#  'chroma_stft_2',
#  'chroma_stft_3',
#  'chroma_stft_4',
#  'chroma_stft_5',
#  'chroma_stft_6',
#  'chroma_stft_7',
#  'chroma_stft_9',
#  'chroma_stft_10',
#  'chroma_stft_11',
#  'tempogram_0',
#  'tempogram_1',
#  'tempogram_2',
#  'tempogram_3',
#  'tempogram_5',
#  'tempogram_8',
#  'tempogram_12',
#  'tempogram_15',
#  'tempogram_18',
#  'tempogram_27',
#  'tempogram_29',
#  'tempogram_35',
#  'tempogram_37',
#  'tempogram_39',
#  'tempogram_40',
#  'tempogram_41',
#  'tempogram_42',
#  'tempogram_45',
#  'tempogram_48',
#  'tempogram_50',
#  'tempogram_54',
#  'tempogram_59',
#  'tempogram_71',
#  'tempogram_81',
#  'tempogram_87',
#  'tempogram_91',
#  'tempogram_93',
#  'tempogram_104',
#  'tempogram_110',
#  'tempogram_114',
#  'tempogram_115',
#  'tempogram_116',
#  'tempogram_123',
#  'tempogram_128',
#  'tempogram_132',
#  'tempogram_144',
#  'tempogram_145',
#  'tempogram_149',
#  'tempogram_152',
#  'tempogram_156',
#  'tempogram_164',
#  'tempogram_165',
#  'tempogram_166',
#  'tempogram_174',
#  'tempogram_180',
#  'tempogram_182',
#  'tempogram_184',
#  'tempogram_188',
#  'tempogram_199',
#  'tempogram_201',
#  'tempogram_204',
#  'tempogram_206',
#  'tempogram_214',
#  'tempogram_216',
#  'tempogram_222',
#  'tempogram_224',
#  'tempogram_227',
#  'tempogram_234',
#  'tempogram_248',
#  'tempogram_250',
#  'tempogram_254',
#  'tempogram_262',
#  'tempogram_264',
#  'tempogram_268',
#  'tempogram_270',
#  'tempogram_272',
#  'tempogram_276',
#  'tempogram_284',
#  'tempogram_289',
#  'tempogram_291',
#  'tempogram_297',
#  'tempogram_298',
#  'tempogram_307',
#  'tempogram_308',
#  'tempogram_310',
#  'tempogram_313',
#  'tempogram_315',
#  'tempogram_336',
#  'tempogram_338',
#  'tempogram_340',
#  'tempogram_366',
#  'tempogram_369',
#  'tempogram_380',
#  'tonnetz_4',
#  'tonnetz_5']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_reduced, y, test_size=0.2, random_state=4)


nb = GaussianNB()

nb=nb.fit(X_train, y_train)
y_pred = nb.predict(X_test)
print('Accuracy' ,accuracy_score(y_test, y_pred))
y_pred1 = nb.predict(X_train)
print('Accuracy train' ,accuracy_score(y_train, y_pred1))
# Out:
# Accuracy 0.651965196519652
# Accuracy train 0.6419354838709678

# %%
classifier = svm.SVC(kernel='rbf',C=10)

classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
print('Accuracy' ,accuracy_score(y_test, y_pred))
y_pred1 = classifier.predict(X_train)
print('Accuracy train' ,accuracy_score(y_train, y_pred1))
# Out:
# Accuracy 0.7425742574257426
# Accuracy train 0.7520630157539385

# %% [markdown]
# ### gridsearch for svm

# %%
X_train = scale(X_train)
#X_train = sc.fit_transform(X_train)
X_test=scale(X_test)

# %%
from sklearn.model_selection import GridSearchCV

tuned_parameters = [
   {"kernel": ["poly"], 'degree' : [2, 3, 4],'C' : [1, 10], 'gamma' : [0.01, 0.03]},
   {"kernel": ["linear"], "C": [1, 10]},
    {"kernel": ["rbf"], "gamma": [0.1, 0.3, 0.5], "C": [1, 10]}
]

clf = GridSearchCV(
    estimator=svm.SVC(),
    param_grid=tuned_parameters,
     scoring='accuracy',
     cv=5,
     verbose=0
)
clf.fit(X_train, y_train)
print(clf.best_params_)
# Out:
# {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
classifier = svm.SVC(kernel='rbf',C=1,gamma=0.1)

classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
print('Accuracy' ,accuracy_score(y_test, y_pred))
y_pred1 = classifier.predict(X_train)
print('Accuracy train' ,accuracy_score(y_train, y_pred1))
# Out:
# Accuracy 0.7611761176117612
# Accuracy train 0.8308327081770442

# %% [markdown]
# ## decision tree with mutual information and scaling

# %%
from sklearn.preprocessing import StandardScaler,scale

X_train, X_test, y_train, y_test = train_test_split(X_reduced, y, test_size=0.2, random_state=4)
X_train = scale(X_train)
#X_train = sc.fit_transform(X_train)
X_test=scale(X_test)

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print('Accuracy' ,accuracy_score(y_test, y_pred))
y_pred1 = clf.predict(X_train)
print('Accuracy train' ,accuracy_score(y_train, y_pred1))
# Out:
# Accuracy 0.633063306330633
# Accuracy train 1.0

# %% [markdown]
# # classification emotion
